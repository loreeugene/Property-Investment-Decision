# %% [markdown]
# ## Property Investment Decision

# %% [markdown]
# Flipping Houses?

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm
from statsmodels.formula.api import ols

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# **Data**

# %%
df  = pd.read_csv('data/kc_house_data.csv')

# %%
df
# Out:
#                id        date     price  bedrooms  bathrooms  sqft_living  \
# 0      7129300520  10/13/2014  221900.0         3       1.00         1180
# 1      6414100192   12/9/2014  538000.0         3       2.25         2570
# 2      5631500400   2/25/2015  180000.0         2       1.00          770
# 3      2487200875   12/9/2014  604000.0         4       3.00         1960
# 4      1954400510   2/18/2015  510000.0         3       2.00         1680
# ...           ...         ...       ...       ...        ...          ...
# 21592   263000018   5/21/2014  360000.0         3       2.50         1530
# 21593  6600060120   2/23/2015  400000.0         4       2.50         2310
# 21594  1523300141   6/23/2014  402101.0         2       0.75         1020
# 21595   291310100   1/16/2015  400000.0         3       2.50         1600
# 21596  1523300157  10/15/2014  325000.0         2       0.75         1020
#
#        sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# 0          5650     1.0         NaN   0.0  ...      7        1180
# 1          7242     2.0         0.0   0.0  ...      7        2170
# 2         10000     1.0         0.0   0.0  ...      6         770
# 3          5000     1.0         0.0   0.0  ...      7        1050
# 4          8080     1.0         0.0   0.0  ...      8        1680
# ...         ...     ...         ...   ...  ...    ...         ...
# 21592      1131     3.0         0.0   0.0  ...      8        1530
# 21593      5813     2.0         0.0   0.0  ...      8        2310
# 21594      1350     2.0         0.0   0.0  ...      7        1020
# 21595      2388     2.0         NaN   0.0  ...      8        1600
# 21596      1076     2.0         0.0   0.0  ...      7        1020
#
#        sqft_basement yr_built  yr_renovated  zipcode      lat     long  \
# 0                0.0     1955           0.0    98178  47.5112 -122.257
# 1              400.0     1951        1991.0    98125  47.7210 -122.319
# 2                0.0     1933           NaN    98028  47.7379 -122.233
# 3              910.0     1965           0.0    98136  47.5208 -122.393
# 4                0.0     1987           0.0    98074  47.6168 -122.045
# ...              ...      ...           ...      ...      ...      ...
# 21592            0.0     2009           0.0    98103  47.6993 -122.346
# 21593            0.0     2014           0.0    98146  47.5107 -122.362
# 21594            0.0     2009           0.0    98144  47.5944 -122.299
# 21595            0.0     2004           0.0    98027  47.5345 -122.069
# 21596            0.0     2008           0.0    98144  47.5941 -122.299
#
#        sqft_living15  sqft_lot15
# 0               1340        5650
# 1               1690        7639
# 2               2720        8062
# 3               1360        5000
# 4               1800        7503
# ...              ...         ...
# 21592           1530        1509
# 21593           1830        7200
# 21594           1020        2007
# 21595           1410        1287
# 21596           1020        1357
#
# [21597 rows x 21 columns]

# %%
df.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %% [markdown]
# *Narrowing down the columns based on the Project 2 suggestions if you're feeling overwhelmed.*

# %%
# Checking the data
data  = df[['id', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
       'sqft_lot', 'floors', 'waterfront', 'condition', 'grade',
       'yr_built']]
data
# Out:
#                id     price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0      7129300520  221900.0         3       1.00         1180      5650
# 1      6414100192  538000.0         3       2.25         2570      7242
# 2      5631500400  180000.0         2       1.00          770     10000
# 3      2487200875  604000.0         4       3.00         1960      5000
# 4      1954400510  510000.0         3       2.00         1680      8080
# ...           ...       ...       ...        ...          ...       ...
# 21592   263000018  360000.0         3       2.50         1530      1131
# 21593  6600060120  400000.0         4       2.50         2310      5813
# 21594  1523300141  402101.0         2       0.75         1020      1350
# 21595   291310100  400000.0         3       2.50         1600      2388
# 21596  1523300157  325000.0         2       0.75         1020      1076
#
#        floors  waterfront  condition  grade  yr_built
# 0         1.0         NaN          3      7      1955
# 1         2.0         0.0          3      7      1951
# 2         1.0         0.0          3      6      1933
# 3         1.0         0.0          5      7      1965
# 4         1.0         0.0          3      8      1987
# ...       ...         ...        ...    ...       ...
# 21592     3.0         0.0          3      8      2009
# 21593     2.0         0.0          3      8      2014
# 21594     2.0         0.0          3      7      2009
# 21595     2.0         NaN          3      8      2004
# 21596     2.0         0.0          3      7      2008
#
# [21597 rows x 11 columns]

# %% [markdown]
# **Cleaning and Preparing**

# %%
# Checking duplicates
data[data.duplicated(keep=False, subset=['id'])]
# Out:
#                id      price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 93     6021501535   430000.0         3       1.50         1580      5000
# 94     6021501535   700000.0         3       1.50         1580      5000
# 313    4139480200  1380000.0         4       3.25         4290     12103
# 314    4139480200  1400000.0         4       3.25         4290     12103
# 324    7520000520   232000.0         2       1.00         1240     12092
# ...           ...        ...       ...        ...          ...       ...
# 20654  8564860270   502000.0         4       2.50         2680      5539
# 20763  6300000226   240000.0         4       1.00         1200      2171
# 20764  6300000226   380000.0         4       1.00         1200      2171
# 21564  7853420110   594866.0         3       3.00         2780      6000
# 21565  7853420110   625000.0         3       3.00         2780      6000
#
#        floors  waterfront  condition  grade  yr_built
# 93        1.0           0          3      8      1939
# 94        1.0           0          3      8      1939
# 313       1.0           0          3     11      1997
# 314       1.0           0          3     11      1997
# 324       1.0           0          3      6      1922
# ...       ...         ...        ...    ...       ...
# 20654     2.0           0          3      8      2013
# 20763     1.5           0          3      7      1933
# 20764     1.5           0          3      7      1933
# 21564     2.0           0          3      9      2013
# 21565     2.0           0          3      9      2013
#
# [353 rows x 11 columns]

# %%
# Removing duplicates and retaining the first row for each duplicate entry.
data = data.drop_duplicates(keep='first', subset=['id'])

# %%
# making ID as index
data.set_index('id', drop=True, append=False, inplace=True)
data.index.name = None

# %%
data
# Out:
#                price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 7129300520  221900.0         3       1.00         1180      5650     1.0
# 6414100192  538000.0         3       2.25         2570      7242     2.0
# 5631500400  180000.0         2       1.00          770     10000     1.0
# 2487200875  604000.0         4       3.00         1960      5000     1.0
# 1954400510  510000.0         3       2.00         1680      8080     1.0
# ...              ...       ...        ...          ...       ...     ...
# 263000018   360000.0         3       2.50         1530      1131     3.0
# 6600060120  400000.0         4       2.50         2310      5813     2.0
# 1523300141  402101.0         2       0.75         1020      1350     2.0
# 291310100   400000.0         3       2.50         1600      2388     2.0
# 1523300157  325000.0         2       0.75         1020      1076     2.0
#
#             waterfront  condition  grade  yr_built
# 7129300520           0          3      7      1955
# 6414100192           0          3      7      1951
# 5631500400           0          3      6      1933
# 2487200875           0          5      7      1965
# 1954400510           0          3      8      1987
# ...                ...        ...    ...       ...
# 263000018            0          3      8      2009
# 6600060120           0          3      8      2014
# 1523300141           0          3      7      2009
# 291310100            0          3      8      2004
# 1523300157           0          3      7      2008
#
# [21420 rows x 10 columns]

# %%
# Checking the info
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21597 entries, 0 to 21596
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           21597 non-null  int64
#  1   price        21597 non-null  float64
#  2   bedrooms     21597 non-null  int64
#  3   bathrooms    21597 non-null  float64
#  4   sqft_living  21597 non-null  int64
#  5   sqft_lot     21597 non-null  int64
#  6   floors       21597 non-null  float64
#  7   waterfront   19221 non-null  float64
#  8   condition    21597 non-null  int64
#  9   grade        21597 non-null  int64
#  10  yr_built     21597 non-null  int64
# dtypes: float64(4), int64(7)
# memory usage: 1.8 MB

# %%
# Check data missing
data.isnull().sum()
# Out:
# id                0
# price             0
# bedrooms          0
# bathrooms         0
# sqft_living       0
# sqft_lot          0
# floors            0
# waterfront     2376
# condition         0
# grade             0
# yr_built          0
# dtype: int64

# %%
data['waterfront'].unique()
# Out:
# array([nan,  0.,  1.])

# %%
# It seems like it's a categorical that answers if the proerty is waterfront or not
df.waterfront.value_counts()
# Out:
# 0.0    19075
# 1.0      146
# Name: waterfront, dtype: int64

# %%
# So filling NA as 0 and converting 'waterfront' to an integer as decimals are unnecessary
data['waterfront'] = data['waterfront'].fillna(0).astype(int)

# %%
data.shape
# Out:
# (21420, 10)

# %%
data.describe()
# Out:
#               price      bedrooms     bathrooms   sqft_living      sqft_lot  \
# count  2.142000e+04  21420.000000  21420.000000  21420.000000  2.142000e+04
# mean   5.407393e+05      3.373950      2.118429   2083.132633  1.512804e+04
# std    3.679311e+05      0.925405      0.768720    918.808412  4.153080e+04
# min    7.800000e+04      1.000000      0.500000    370.000000  5.200000e+02
# 25%    3.225000e+05      3.000000      1.750000   1430.000000  5.040000e+03
# 50%    4.500000e+05      3.000000      2.250000   1920.000000  7.614000e+03
# 75%    6.450000e+05      4.000000      2.500000   2550.000000  1.069050e+04
# max    7.700000e+06     33.000000      8.000000  13540.000000  1.651359e+06
#
#              floors    waterfront     condition         grade      yr_built
# count  21420.000000  21420.000000  21420.000000  21420.000000  21420.000000
# mean       1.495985      0.006816      3.410784      7.662792   1971.092997
# std        0.540081      0.082280      0.650035      1.171971     29.387141
# min        1.000000      0.000000      1.000000      3.000000   1900.000000
# 25%        1.000000      0.000000      3.000000      7.000000   1952.000000
# 50%        1.500000      0.000000      3.000000      7.000000   1975.000000
# 75%        2.000000      0.000000      4.000000      8.000000   1997.000000
# max        3.500000      1.000000      5.000000     13.000000   2015.000000

# %% [markdown]
# Noticed a weird number in the bedrooms column

# %%
# Checking
data['bedrooms'].unique()
# Out:
# array([ 3,  2,  4,  5,  1,  6,  7,  8,  9, 11, 10, 33])

# %%
# Noticed a different number which is 33, checking details
data[data['bedrooms'] == 33]
# Out:
#                price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 2402100895  640000.0        33       1.75         1620      6000     1.0
#
#             waterfront  condition  grade  yr_built
# 2402100895           0          5      7      1947

# %%
# One house has 33 bedrooms and sqft_living of 1620. This is below the mean
# It is unlikely this house has 33 bedrooms, possibly a recording error
data['bedrooms'] = data['bedrooms'].replace(33, 3)

# %%
# Rechecking
data[data['bedrooms'] == 33]
# Out:
# Empty DataFrame
# Columns: [price, bedrooms, bathrooms, sqft_living, sqft_lot, floors, waterfront, condition, grade, yr_built]
# Index: []

# %% [markdown]
# **Continues vs Categorical**

# %%
sns.pairplot(data);

# %%
data.nunique()
# Out:
# price          3607
# bedrooms         11
# bathrooms        29
# sqft_living    1034
# sqft_lot       9776
# floors            6
# waterfront        2
# condition         5
# grade            11
# yr_built        116
# dtype: int64

# %% [markdown]
# Seems like we have the following in:
#
# Continues variables:
# - price
# - sqft_living
# - sqft_lot
#
# Categorical variables:
# - bedrooms
# - bathrooms
# - floors
# - waterfront
# - condition
# - grade
# - yr_built

# %%
# I feel like bathrooms has too much categories, checking
data['bathrooms'].unique()
# Out:
# array([1.  , 2.25, 3.  , 2.  , 4.5 , 1.5 , 2.5 , 1.75, 2.75, 3.25, 4.  ,
#        3.5 , 0.75, 4.75, 5.  , 4.25, 3.75, 1.25, 5.25, 6.  , 0.5 , 5.5 ,
#        6.75, 5.75, 8.  , 7.5 , 7.75, 6.25, 6.5 ])

# %%
# narrowing it down to whole numbers
data['bathrooms'] = data['bathrooms'].round().astype(int)

# %%
data['bathrooms'].unique()
# Out:
# array([1, 2, 3, 4, 5, 6, 0, 7, 8])

# %%
# Same as the yr_built, checking
unique_years = data['yr_built'].unique()
np.sort(unique_years)
# Out:
# array([1900, 1901, 1902, 1903, 1904, 1905, 1906, 1907, 1908, 1909, 1910,
#        1911, 1912, 1913, 1914, 1915, 1916, 1917, 1918, 1919, 1920, 1921,
#        1922, 1923, 1924, 1925, 1926, 1927, 1928, 1929, 1930, 1931, 1932,
#        1933, 1934, 1935, 1936, 1937, 1938, 1939, 1940, 1941, 1942, 1943,
#        1944, 1945, 1946, 1947, 1948, 1949, 1950, 1951, 1952, 1953, 1954,
#        1955, 1956, 1957, 1958, 1959, 1960, 1961, 1962, 1963, 1964, 1965,
#        1966, 1967, 1968, 1969, 1970, 1971, 1972, 1973, 1974, 1975, 1976,
#        1977, 1978, 1979, 1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987,
#        1988, 1989, 1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998,
#        1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009,
#        2010, 2011, 2012, 2013, 2014, 2015])

# %%
# Narrowing it down to a 3 bins categorised by half century
# Convert yr_built;
# 1900 to 1950 = yr_1900-1950
# 1951 to 2000 = yr_1951-1900
# 2001 to 2015 = yr_2001-2015

def half_cent(year):
    if 1899 < year < 1951:
        return 1
    elif 1950 < year < 2000:
        return 2
    else: return 3

# %%
data['yr_built'] = data['yr_built'].apply(half_cent)

# %%
data
# Out:
#                price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 7129300520  221900.0         3          1         1180      5650     1.0
# 6414100192  538000.0         3          2         2570      7242     2.0
# 5631500400  180000.0         2          1          770     10000     1.0
# 2487200875  604000.0         4          3         1960      5000     1.0
# 1954400510  510000.0         3          2         1680      8080     1.0
# ...              ...       ...        ...          ...       ...     ...
# 263000018   360000.0         3          2         1530      1131     3.0
# 6600060120  400000.0         4          2         2310      5813     2.0
# 1523300141  402101.0         2          1         1020      1350     2.0
# 291310100   400000.0         3          2         1600      2388     2.0
# 1523300157  325000.0         2          1         1020      1076     2.0
#
#             waterfront  condition  grade  yr_built
# 7129300520           0          3      7         2
# 6414100192           0          3      7         2
# 5631500400           0          3      6         1
# 2487200875           0          5      7         2
# 1954400510           0          3      8         2
# ...                ...        ...    ...       ...
# 263000018            0          3      8         3
# 6600060120           0          3      8         3
# 1523300141           0          3      7         3
# 291310100            0          3      8         3
# 1523300157           0          3      7         3
#
# [21420 rows x 10 columns]

# %%
# rounding off floors
data['floors'].unique()

# %%
data['floors'] = data['floors'].round().astype(int)

# %%
data.nunique()
# Out:
# price          3607
# bedrooms         11
# bathrooms         9
# sqft_living    1034
# sqft_lot       9776
# floors            4
# waterfront        2
# condition         5
# grade            11
# yr_built          3
# dtype: int64

# %% [markdown]
# Now, we have the following in:
#
# Continues variables:
# - price
# - sqft_living
# - sqft_lot
#
#
# Categorical variables:
# - bedrooms
# - bathrooms
# - floors
# - waterfront
# - grade
# - yr_built

# %% [markdown]
# Seems like I am satisfied with our exploratory data analysis (EDA). Now, let's proceed to build our first iteration.

# %% [markdown]
# ---
# ## Iteration 1

# %%
data.columns
# Out:
# Index(['price', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot', 'floors',
#        'waterfront', 'condition', 'grade', 'yr_built'],
#       dtype='object')

# %%
# Creating new df to avoid messing with the original one
df1 = data.copy()

# %%
# creating dummies of categorical variables
bedr_dummies = pd.get_dummies(df1['bedrooms'], prefix='bedr', drop_first=True)
bathr_dummies = pd.get_dummies(df1['bathrooms'], prefix='bathr', drop_first=True)
floors_dummies = pd.get_dummies(df1['floors'], prefix='floors', drop_first=True)
waterfr_dummies = pd.get_dummies(df1['waterfront'], prefix='waterfr', drop_first=True)
cond_dummies = pd.get_dummies(df1['condition'], prefix='cond', drop_first=True)
grade_dummies = pd.get_dummies(df1['grade'], prefix='grade', drop_first=True)
yr_built_dummies = pd.get_dummies(df1['yr_built'], prefix='yr_built', drop_first=True)

# %%
# dropping off columns
df1 = df1.drop(['bedrooms','bathrooms','floors','waterfront','condition','grade','yr_built'], axis=1)

# %%
# combining new data and the dummy columns
df1 = pd.concat([df1, bedr_dummies, bathr_dummies, floors_dummies, waterfr_dummies, cond_dummies, grade_dummies, yr_built_dummies], axis=1)

# %%
# making the first iteration
Y = 'price'
X1 = df1.drop(['price'], axis = 1)
X1_columns = "+".join(X1.columns)

# %%
ols_formula = Y + "~" + X1_columns

OLS = ols(formula = ols_formula, data = df1)
model = OLS.fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.673
# Model:                            OLS   Adj. R-squared:                  0.673
# Method:                 Least Squares   F-statistic:                     1101.
# Date:                Wed, 27 Sep 2023   Prob (F-statistic):               0.00
# Time:                        10:52:56   Log-Likelihood:            -2.9292e+05
# No. Observations:               21420   AIC:                         5.859e+05
# Df Residuals:                   21379   BIC:                         5.863e+05
# Df Model:                          40
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept   -1.847e+04   2.39e+05     -0.077      0.938   -4.87e+05     4.5e+05
# sqft_living   151.5138      3.303     45.867      0.000     145.039     157.989
# sqft_lot       -0.2761      0.036     -7.742      0.000      -0.346      -0.206
# bedr_2       -673.3283   1.62e+04     -0.042      0.967   -3.24e+04     3.1e+04
# bedr_3      -2.299e+04   1.62e+04     -1.418      0.156   -5.48e+04    8779.180
# bedr_4      -5.323e+04   1.65e+04     -3.219      0.001   -8.56e+04   -2.08e+04
# bedr_5      -4.011e+04   1.74e+04     -2.302      0.021   -7.43e+04   -5961.333
# bedr_6      -7.174e+04   2.13e+04     -3.371      0.001   -1.13e+05      -3e+04
# bedr_7      -1.499e+05   3.87e+04     -3.872      0.000   -2.26e+05    -7.4e+04
# bedr_8       7.978e+04   6.14e+04      1.299      0.194   -4.06e+04       2e+05
# bedr_9      -3.613e+05   8.97e+04     -4.027      0.000   -5.37e+05   -1.85e+05
# bedr_10     -1.332e+05   1.23e+05     -1.082      0.279   -3.75e+05    1.08e+05
# bedr_11     -2.357e+05   2.11e+05     -1.115      0.265    -6.5e+05    1.78e+05
# bathr_1       1.07e+05   1.05e+05      1.015      0.310   -9.96e+04    3.14e+05
# %%
fig, axes = plt.subplots(1, 3, figsize = (20,5))
columns = ['sqft_living', 'sqft_lot','price']

sns.histplot(data=df1, x="sqft_living", kde=True, ax=axes[0])
sns.histplot(data=df1, x="sqft_lot", kde=True, ax=axes[1])
sns.histplot(data=df1, x="price", kde=True, ax=axes[2])

plt.tight_layout()
plt.show()

# %% [markdown]
# We have positive skewness in our continuous variables
#
# - price
# - sqft_living
# - sqft_lot
#
# Positive skewness means that the tails of the distributions for these variables are longer on the right side (toward higher values), and most of the data points are concentrated on the left side (toward lower values).

# %% [markdown]
# **Model assumption: Linearity**
#
# Identify which variables have a linear relationship with the target variable price

# %%
# sqft_living + sqft_above + sqft_basement + sqft_lot + sqft_living15 + sqft_lot15

fig, axes = plt.subplots(1, 2, figsize = (15,5))

sns.scatterplot(x = df1['sqft_living'], y = df1['price'],ax=axes[0])
axes[0].set_title("sqft_living and price")

sns.scatterplot(x = df1['sqft_lot'], y = df1['price'],ax=axes[1])
axes[1].set_title("sqft_lot and price")

plt.tight_layout()
plt.show()

# %% [markdown]
# * sqft_living shows a strong linear relationship with price.
# * sqft_lot shows a weak linear relationship with price.

# %% [markdown]
# **Model assumption: Normality**
#
# * **Plot 1**: Histogram of the residuals
# * **Plot 2**: Q-Q plot of the residuals

# %%
# Calculate the residuals.
residuals = model.resid

fig, axes = plt.subplots(1, 2, figsize = (8,4))

sns.histplot(residuals, ax=axes[0])
axes[0].set_xlabel("Residual Value")
axes[0].set_title("Histogram of Residuals")

sm.qqplot(residuals, line='s',ax = axes[1])
axes[1].set_title("QQ Plot")

plt.tight_layout()
plt.show()

# %% [markdown]
# - I observe a mild positive skewness in the histogram, as well as heavier tails compared to the normal distribution
# - The residuals in the Q-Q plot appear to align quite closely with a straight line, indicating approximate normality. However, it's worth investigating the larger residuals to assess potential outliers.

# %% [markdown]
# **Model assumption: Constant variance**

# %%
# Create a scatterplot with the fitted values from the model and the residuals.
fig = sns.scatterplot(x = model.fittedvalues, y = model.resid)

fig.set_xlabel("Fitted Values")
fig.set_ylabel("Residuals")
fig.set_title("Fitted Values v. Residuals")
fig.axhline(0)

plt.show()

# %% [markdown]
# The variance of the residuals increases with X, indicating a violation of the constant variance assumption.

# %% [markdown]
# **Model assumption: No multicollinearity**

# %%
# Calculate the variance inflation factor (optional).

# variance_inflation_factor from statsmodels.
from statsmodels.stats.outliers_influence import variance_inflation_factor

# subset of the data with the continous independent variables. 
X = df1[['sqft_living','sqft_lot']]

# variance inflation factor for each variable.
vif = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]

# DataFrame with the VIF results for the column names in X.
df_vif = pd.DataFrame(vif, index=X.columns, columns = ['VIF'])

# Display the VIF results.
df_vif
# Out:
#                   VIF
# sqft_living  1.167323
# sqft_lot     1.167323

# %% [markdown]
# Given that both "sqft_living" and "sqft_lot" have VIF values close to 1, it suggests that they are not highly correlated with each other or with other predictor variables in your regression model. This is a positive finding, as it indicates that multicollinearity is not a significant concern for these particular variables.

# %% [markdown]
# We will explore correlation.

# %%
df1.corr()
# Out:
#                 price  sqft_living  sqft_lot    bedr_2    bedr_3    bedr_4  \
# grade_7     -0.527866 -0.313459 -0.198761 -0.115591 -0.054095 -0.020755
# grade_8      1.000000 -0.233258 -0.147907 -0.086016 -0.040255 -0.015445
# grade_9     -0.233258  1.000000 -0.087830 -0.051078 -0.023904 -0.009172
# grade_10    -0.147907 -0.087830  1.000000 -0.032388 -0.015157 -0.005816
# grade_11    -0.086016 -0.051078 -0.032388  1.000000 -0.008815 -0.003382
# grade_12    -0.040255 -0.023904 -0.015157 -0.008815  1.000000 -0.001583
# grade_13    -0.015445 -0.009172 -0.005816 -0.003382 -0.001583  1.000000
# yr_built_2   0.021803 -0.047436  0.007763 -0.012922  0.006643 -0.007650
# yr_built_3   0.145681  0.194609  0.085869  0.075364  0.018474  0.009682
#
#              yr_built_2  yr_built_3
# price         -0.100325    0.113261
# sqft_living    0.021300    0.226022
# sqft_lot       0.085375   -0.037862
# bedr_2        -0.224389   -0.024574
# bedr_3         0.142396   -0.075508
# bedr_4         0.020274    0.083920
# bedr_5        -0.003727    0.050126
# bedr_6         0.014464   -0.024097
# bedr_7         0.010026   -0.011798
# bedr_8         0.011365   -0.013144
# bedr_9        -0.012516   -0.008928
# bedr_10       -0.004892    0.003188
# bedr_11       -0.007394   -0.003644
# bathr_1       -0.128477   -0.237728
# bathr_2        0.169850    0.021764
# bathr_3       -0.023998    0.100233
# bathr_4       -0.097930    0.198862
# bathr_5       -0.017714    0.035739
# bathr_6       -0.025042    0.042629
# bathr_7        0.008930   -0.005154
# bathr_8       -0.001079    0.000939
# floors_2      -0.269893    0.371681
# floors_3      -0.143966    0.266610
# floors_4      -0.014382    0.021458
# waterfr_1      0.000289   -0.020955
# cond_2        -0.014460   -0.046561
# cond_3        -0.144433    0.384771
# cond_4         0.176992   -0.311327
# cond_5        -0.025694   -0.155116
# grade_4       -0.033162   -0.018948
# grade_5       -0.080382   -0.053891
# grade_6       -0.152119   -0.164353
# grade_7        0.120264   -0.214878
# grade_8        0.021803    0.145681
# grade_9       -0.047436    0.194609
# grade_10       0.007763    0.085869
# grade_11      -0.012922    0.075364
# grade_12       0.006643    0.018474
# grade_13      -0.007650    0.009682
# yr_built_2     1.000000   -0.577140
# yr_built_3    -0.577140    1.000000
#
# [41 rows x 41 columns]

# %%
abs(df1.corr()) > 0.75
# Out:
#              price  sqft_living  sqft_lot  bedr_2  bedr_3  bedr_4  bedr_5  \
# price         True        False     False   False   False   False   False
# sqft_living  False         True     False   False   False   False   False
# sqft_lot     False        False      True   False   False   False   False
# bedr_2       False        False     False    True   False   False   False
# bedr_3       False        False     False   False    True   False   False
# bedr_4       False        False     False   False   False    True   False
# bedr_5       False        False     False   False   False   False    True
# bedr_6       False        False     False   False   False   False   False
# bedr_7       False        False     False   False   False   False   False
# bedr_8       False        False     False   False   False   False   False
# bedr_9       False        False     False   False   False   False   False
# bedr_10      False        False     False   False   False   False   False
# bedr_11      False        False     False   False   False   False   False
# bathr_1      False        False     False   False   False   False   False
# bathr_2      False        False     False   False   False   False   False
# bathr_3      False        False     False   False   False   False   False
# bathr_4      False        False     False   False   False   False   False
# bathr_5      False        False     False   False   False   False   False
# bathr_6      False        False     False   False   False   False   False
# bathr_7      False        False     False   False   False   False   False
# bathr_8      False        False     False   False   False   False   False
# floors_2     False        False     False   False   False   False   False
# floors_3     False        False     False   False   False   False   False
# floors_4     False        False     False   False   False   False   False
# waterfr_1    False        False     False   False   False   False   False
# cond_2       False        False     False   False   False   False   False
# cond_3       False        False     False   False   False   False   False
# cond_4       False        False     False   False   False   False   False
# cond_5       False        False     False   False   False   False   False
# grade_4      False        False     False   False   False   False   False
# grade_5      False        False     False   False   False   False   False
# grade_6      False        False     False   False   False   False   False
# grade_7      False        False     False   False   False   False   False
# grade_8      False        False     False   False   False   False   False
# grade_9      False        False     False   False   False   False   False
# grade_10     False        False     False   False   False   False   False
# grade_11     False        False     False   False   False   False   False
# grade_12     False        False     False   False   False   False   False
# grade_13     False        False     False   False   False   False   False
# yr_built_2   False        False     False   False   False   False   False
# yr_built_3   False        False     False   False   False   False   False
#
#              bedr_6  bedr_7  bedr_8  ...  grade_6  grade_7  grade_8  grade_9  \
# price         False   False   False  ...    False    False    False    False
# sqft_living   False   False   False  ...    False    False    False    False
# sqft_lot      False   False   False  ...    False    False    False    False
# bedr_2        False   False   False  ...    False    False    False    False
# bedr_3        False   False   False  ...    False    False    False    False
# bedr_4        False   False   False  ...    False    False    False    False
# bedr_5        False   False   False  ...    False    False    False    False
# bedr_6         True   False   False  ...    False    False    False    False
# bedr_7        False    True   False  ...    False    False    False    False
# bedr_8        False   False    True  ...    False    False    False    False
# bedr_9        False   False   False  ...    False    False    False    False
# bedr_10       False   False   False  ...    False    False    False    False
# bedr_11       False   False   False  ...    False    False    False    False
# bathr_1       False   False   False  ...    False    False    False    False
# bathr_2       False   False   False  ...    False    False    False    False
# bathr_3       False   False   False  ...    False    False    False    False
# bathr_4       False   False   False  ...    False    False    False    False
# bathr_5       False   False   False  ...    False    False    False    False
# bathr_6       False   False   False  ...    False    False    False    False
# bathr_7       False   False   False  ...    False    False    False    False
# bathr_8       False   False   False  ...    False    False    False    False
# floors_2      False   False   False  ...    False    False    False    False
# floors_3      False   False   False  ...    False    False    False    False
# floors_4      False   False   False  ...    False    False    False    False
# waterfr_1     False   False   False  ...    False    False    False    False
# cond_2        False   False   False  ...    False    False    False    False
# cond_3        False   False   False  ...    False    False    False    False
# cond_4        False   False   False  ...    False    False    False    False
# cond_5        False   False   False  ...    False    False    False    False
# grade_4       False   False   False  ...    False    False    False    False
# grade_5       False   False   False  ...    False    False    False    False
# grade_6       False   False   False  ...     True    False    False    False
# grade_7       False   False   False  ...    False     True    False    False
# grade_8       False   False   False  ...    False    False     True    False
# grade_9       False   False   False  ...    False    False    False     True
# grade_10      False   False   False  ...    False    False    False    False
# grade_11      False   False   False  ...    False    False    False    False
# grade_12      False   False   False  ...    False    False    False    False
# grade_13      False   False   False  ...    False    False    False    False
# yr_built_2    False   False   False  ...    False    False    False    False
# yr_built_3    False   False   False  ...    False    False    False    False
#
#              grade_10  grade_11  grade_12  grade_13  yr_built_2  yr_built_3
# price           False     False     False     False       False       False
# sqft_living     False     False     False     False       False       False
# sqft_lot        False     False     False     False       False       False
# bedr_2          False     False     False     False       False       False
# bedr_3          False     False     False     False       False       False
# bedr_4          False     False     False     False       False       False
# bedr_5          False     False     False     False       False       False
# bedr_6          False     False     False     False       False       False
# bedr_7          False     False     False     False       False       False
# bedr_8          False     False     False     False       False       False
# bedr_9          False     False     False     False       False       False
# bedr_10         False     False     False     False       False       False
# bedr_11         False     False     False     False       False       False
# bathr_1         False     False     False     False       False       False
# bathr_2         False     False     False     False       False       False
# bathr_3         False     False     False     False       False       False
# bathr_4         False     False     False     False       False       False
# bathr_5         False     False     False     False       False       False
# bathr_6         False     False     False     False       False       False
# bathr_7         False     False     False     False       False       False
# bathr_8         False     False     False     False       False       False
# floors_2        False     False     False     False       False       False
# floors_3        False     False     False     False       False       False
# floors_4        False     False     False     False       False       False
# waterfr_1       False     False     False     False       False       False
# cond_2          False     False     False     False       False       False
# cond_3          False     False     False     False       False       False
# cond_4          False     False     False     False       False       False
# cond_5          False     False     False     False       False       False
# grade_4         False     False     False     False       False       False
# grade_5         False     False     False     False       False       False
# grade_6         False     False     False     False       False       False
# grade_7         False     False     False     False       False       False
# grade_8         False     False     False     False       False       False
# grade_9         False     False     False     False       False       False
# grade_10         True     False     False     False       False       False
# grade_11        False      True     False     False       False       False
# grade_12        False     False      True     False       False       False
# grade_13        False     False     False      True       False       False
# yr_built_2      False     False     False     False        True       False
# yr_built_3      False     False     False     False       False        True
#
# [41 rows x 41 columns]

# %%
df=df1.corr().abs().stack().reset_index().sort_values(0, ascending=False)

# zip the variable name columns (Which were only named level_0 and level_1 by default) in a new column named "pairs"
df['pairs'] = list(zip(df.level_0, df.level_1))
df.set_index(['pairs'], inplace = True)
df.drop(columns=['level_1', 'level_0'], inplace = True)
df.columns = ['cc']
df.drop_duplicates(inplace=True)

# %%
df[(df.cc>.75) & (df.cc <1)]
# Out:
#                         cc
# pairs
# (cond_4, cond_3)  0.813095

# %% [markdown]
# The correlation coefficient between "cond_4" and "cond_3" is approximately 0.813095. This indicates a strong positive linear relationship or correlation between these two variables.

# %% [markdown]
# ___
# # Iteration 2

# %% [markdown]
# **Adjustments**: Addressing issues in Iteration 1 (First Model)
# 1. Despite sqft_lot's weak linear relationship with price, we retain it due to prior variable reductions in our smaller datase
# 2. We'll drop cond_4, cond_3 as we've seen in the correlation table.
# 3. Regarding normality, we will investigate the presence of outliers and take steps to address them.
# 4. We will apply Log Transformation to handle the distribution and skewness of our data.

# %%
# droppping 'cond_4', 'cond_3'
df2 = df1.drop(columns=['cond_4', 'cond_3'])

# %% [markdown]
# **Relevant continues variables vs the dependent variable**

# %%
fig, axes = plt.subplots(1, 2, figsize = (20,5))

sns.histplot(data=df2, x="sqft_living", kde=True, ax=axes[0])
sns.histplot(data=df2, x="price", kde=True, ax=axes[1])

plt.tight_layout()
plt.show()

# %% [markdown]
# **Taking outliers**

# %%
# Taking utliers by reducing data size to 3 standard deviations

filter_cols = ['sqft_living', 'price', 'sqft_lot']

df2 = df2[~df2[filter_cols].apply(lambda x: np.abs(x - x.mean()) > 3 * x.std()).any(axis=1)]

# %%
fig, axes = plt.subplots(1, 2, figsize = (20,5))

sns.histplot(data=df2, x="sqft_living", kde=True, ax=axes[0])
sns.histplot(data=df2, x="price", kde=True, ax=axes[1])

plt.tight_layout()
plt.show()

# %% [markdown]
# Simply by reducing the data size to exclude values beyond three standard deviations, we've observed an improvement in our dataset

# %% [markdown]
# **Log Transformation**

# %%
df2['sqft_living'] = np.log(df2['sqft_living'])
df2['price'] = np.log(df2['price'])

# %%
fig, axes = plt.subplots(1, 2, figsize = (20,5))

sns.histplot(data=df2, x="sqft_living", kde=True, ax=axes[0])
sns.histplot(data=df2, x="price", kde=True, ax=axes[1])

plt.tight_layout()
plt.show()

# %% [markdown]
# Applying a log transformation to our data has significantly improved its skewness

# %% [markdown]
# **Standardisation (Z-score Normalisation)**
#
# Scaling and centering the data using Z-score normalization, also known as standard scaling

# %%
# normalize (subract mean and divide by std)

df2['sqft_living'] = (df2['sqft_living'] - df2['sqft_living'].mean()) / df2['sqft_living'].std()
df2['price'] = (df2['price'] - df2['price'].mean()) / df2['price'].std()

# %%
fig, axes = plt.subplots(1, 2, figsize = (20,5))

sns.histplot(data=df2, x="sqft_living", kde=True, ax=axes[0])
sns.histplot(data=df2, x="price", kde=True, ax=axes[1])

plt.tight_layout()
plt.show()

# %% [markdown]
# It's important to note that standardization doesn't change the shape of the data's distribution; it only scales and centers the data.

# %%
# Doing the second iteration
X2 = df2.drop(['price'], axis = 1)
X2_columns = "+".join(X2.columns)

# %%
ols_formula = Y + "~" + X2_columns

OLS = ols(formula = ols_formula, data = df2)
model2 = OLS.fit()
model2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.585
# Model:                            OLS   Adj. R-squared:                  0.584
# Method:                 Least Squares   F-statistic:                     804.7
# Date:                Wed, 27 Sep 2023   Prob (F-statistic):               0.00
# Time:                        10:53:01   Log-Likelihood:                -20157.
# No. Observations:               20586   AIC:                         4.039e+04
# Df Residuals:                   20549   BIC:                         4.068e+04
# Df Model:                          36
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept      -0.8114      0.722     -1.124      0.261      -2.226       0.603
# sqft_living     0.3788      0.009     42.198      0.000       0.361       0.396
# sqft_lot    -1.001e-06   3.56e-07     -2.814      0.005    -1.7e-06   -3.04e-07
# bedr_2         -0.1094      0.050     -2.177      0.029      -0.208      -0.011
# bedr_3         -0.2666      0.051     -5.257      0.000      -0.366      -0.167
# bedr_4         -0.3087      0.052     -5.923      0.000      -0.411      -0.207
# bedr_5         -0.2781      0.055     -5.050      0.000      -0.386      -0.170
# bedr_6         -0.3306      0.068     -4.832      0.000      -0.465      -0.196
# bedr_7         -0.3816      0.136     -2.816      0.005      -0.647      -0.116
# bedr_8         -0.2868      0.223     -1.288      0.198      -0.723       0.150
# bedr_9         -0.1769      0.294     -0.602      0.547      -0.753       0.399
# bedr_10         0.1333      0.380      0.351      0.726      -0.612       0.879
# bedr_11        -0.7249      0.647     -1.120      0.263      -1.994       0.544
# bathr_1         0.6864      0.323      2.126      0.034       0.054       1.319
# bathr_2         0.7310      0.323      2.263      0.024       0.098       1.364
# bathr_3         0.8523      0.323      2.636      0.008       0.218       1.486
# bathr_4         0.9700      0.324      2.994      0.003       0.335       1.605
# bathr_5         0.8866      0.363      2.443      0.015       0.175       1.598
# bathr_6        -0.0860      0.732     -0.118      0.906      -1.521       1.349
# bathr_7      1.602e-13   1.46e-13      1.097      0.273   -1.26e-13    4.46e-13
# bathr_8         0.4005      0.777      0.515      0.606      -1.123       1.924
# floors_2       -0.0534      0.011     -4.710      0.000      -0.076      -0.031
# floors_3        0.2892      0.030      9.585      0.000       0.230       0.348
# floors_4        0.3362      0.264      1.275      0.202      -0.181       0.853
# waterfr_1       0.9312      0.074     12.584      0.000       0.786       1.076
# cond_2         -0.3905      0.053     -7.369      0.000      -0.494      -0.287
# cond_5          0.2253      0.017     13.059      0.000       0.191       0.259
# grade_4        -0.4636      0.657     -0.705      0.481      -1.752       0.825
# grade_5        -0.4213      0.648     -0.650      0.515      -1.691       0.848
# grade_6         0.0067      0.647      0.010      0.992      -1.261       1.275
# grade_7         0.6034      0.647      0.933      0.351      -0.665       1.872
# grade_8         1.0820      0.647      1.672      0.095      -0.187       2.351
# grade_9         1.5662      0.647      2.419      0.016       0.297       2.835
# grade_10        1.8866      0.648      2.912      0.004       0.617       3.156
# grade_11        2.1460      0.649      3.306      0.001       0.874       3.418
# grade_12        2.4253      0.662      3.662      0.000       1.127       3.723
# grade_13             0          0        nan        nan           0           0
# yr_built_2     -0.6782      0.013    -52.556      0.000      -0.704      -0.653
# yr_built_3     -0.7522      0.016    -46.396      0.000      -0.784      -0.720
# ==============================================================================
# Omnibus:                       69.629   Durbin-Watson:                   1.970
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               87.585
# Skew:                          -0.056   Prob(JB):                     9.58e-20
# Kurtosis:                       3.300   Cond. No.                     1.27e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 3.82e-20. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """

# %% [markdown]
# **Model assumption: Linearity**
#
# Identify which variables have a linear relationship with the target variable price

# %%
fig = sns.scatterplot(x = df1['sqft_living'], y = df1['price'])
fig.set_title("sqft_lot and price")

plt.show()

# %% [markdown]
# **Model assumption: Normality**
#
# * **Plot 1**: Histogram of the residuals
# * **Plot 2**: Q-Q plot of the residuals

# %%
# Calculate the residuals.
residuals = model2.resid

fig, axes = plt.subplots(1, 2, figsize = (8,4))

sns.histplot(residuals, ax=axes[0])
axes[0].set_xlabel("Residual Value")
axes[0].set_title("Histogram of Residuals")

sm.qqplot(residuals, line='s',ax = axes[1])
axes[1].set_title("QQ Plot")

plt.tight_layout()
plt.show()

# %% [markdown]
# - The histogram of residuals has shown significant improvement, with a notable reduction in heavy tails.
# - Also, the QQ plot now exhibits a smoother and closer alignment between sample quantiles and theoretical quantiles, forming a more linear relationship.
# - But the QQ plot displays some data points that could potentially be outliers

# %% [markdown]
# **Model assumption: Constant variance**

# %%
fig = sns.scatterplot(x = model2.fittedvalues, y = model2.resid)

fig.set_xlabel("Fitted Values")
fig.set_ylabel("Residuals")
fig.set_title("Fitted Values v. Residuals")
fig.axhline(0)

plt.show()

# %% [markdown]
# **Model assumption: No multicollinearity**

# %%
df2.corr()
# Out:
#                 price  sqft_living  sqft_lot    bedr_2    bedr_3    bedr_4  \
# price        1.000000     0.630802  0.100389 -0.175266 -0.172025  0.229912
# sqft_living  0.630802     1.000000  0.211168 -0.450103 -0.206560  0.413036
# sqft_lot     0.100389     0.211168  1.000000 -0.080162 -0.018813  0.061550
# grade_4         False     False     False     False       False       False
# grade_5         False     False     False     False       False       False
# grade_6         False     False     False     False       False       False
# grade_7         False     False     False     False       False       False
# grade_8         False     False     False     False       False       False
# grade_9         False     False     False     False       False       False
# grade_10         True     False     False     False       False       False
# grade_11        False      True     False     False       False       False
# grade_12        False     False      True     False       False       False
# grade_13        False     False     False      True       False       False
# yr_built_2      False     False     False     False        True       False
# yr_built_3      False     False     False     False       False        True
#
# [41 rows x 41 columns]

# %%
df=df2.corr().abs().stack().reset_index().sort_values(0, ascending=False)

# zip the variable name columns (Which were only named level_0 and level_1 by default) in a new column named "pairs"
df['pairs'] = list(zip(df.level_0, df.level_1))
df.set_index(['pairs'], inplace = True)
df.drop(columns=['level_1', 'level_0'], inplace = True)
df.columns = ['cc']
df.drop_duplicates(inplace=True)

# %%
df[(df.cc>.75) & (df.cc <1)]
# Out:
#                         cc
# pairs
# (cond_4, cond_3)  0.813095

# %% [markdown]
# ---
# # Iteration 3

# %%
df3 = df2.copy()

# %%
# Reduce outliers by reducing data size to 2 standard deviations

column= ['price', 'sqft_living']

df3 = df3[~df3[column].apply(lambda x: np.abs(x - x.mean()) > 2 * x.std()).any(axis=1)]

# %%
X3 = df3.drop(['price'], axis = 1)
X3_columns = "+".join(X3.columns)

# %%
ols_formula = Y + "~" + X3_columns

OLS = ols(formula = ols_formula, data = df3)
model3 = OLS.fit()
model3.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.516
# Model:                            OLS   Adj. R-squared:                  0.515
# Method:                 Least Squares   F-statistic:                     577.3
# Date:                Wed, 27 Sep 2023   Prob (F-statistic):               0.00
# Time:                        10:53:02   Log-Likelihood:                -17402.
# No. Observations:               18974   AIC:                         3.488e+04
# Df Residuals:                   18938   BIC:                         3.516e+04
# Df Model:                          35
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept       0.0702      0.330      0.213      0.832      -0.576       0.717
# sqft_living     0.3514      0.009     39.062      0.000       0.334       0.369
# sqft_lot    -3.243e-07   3.51e-07     -0.925      0.355   -1.01e-06    3.63e-07
# bedr_2         -0.0155      0.075     -0.206      0.837      -0.163       0.132
# bedr_3         -0.1639      0.075     -2.182      0.029      -0.311      -0.017
# bedr_4         -0.1996      0.076     -2.635      0.008      -0.348      -0.051
# bedr_5         -0.2009      0.078     -2.585      0.010      -0.353      -0.049
# bedr_6         -0.1896      0.087     -2.171      0.030      -0.361      -0.018
# bedr_7         -0.2093      0.146     -1.436      0.151      -0.495       0.076
# bedr_8         -0.0047      0.229     -0.021      0.983      -0.454       0.444
# bedr_9         -0.0019      0.359     -0.005      0.996      -0.705       0.701
# bedr_10         0.2273      0.436      0.522      0.602      -0.626       1.081
# bedr_11        -0.5706      0.611     -0.934      0.350      -1.768       0.627
# bathr_1         0.5716      0.351      1.629      0.103      -0.116       1.260
# bathr_2         0.5789      0.351      1.649      0.099      -0.109       1.267
# bathr_3         0.6903      0.351      1.965      0.049       0.002       1.379
# bathr_4         0.7808      0.352      2.218      0.027       0.091       1.471
# bathr_5         0.6535      0.397      1.645      0.100      -0.125       1.432
# bathr_6        -0.2377      0.711     -0.334      0.738      -1.632       1.157
# bathr_7      5.645e-16   1.55e-15      0.364      0.716   -2.48e-15    3.61e-15
# bathr_8         0.2193      0.783      0.280      0.779      -1.316       1.754
# floors_2       -0.0475      0.011     -4.333      0.000      -0.069      -0.026
# floors_3        0.2786      0.029      9.533      0.000       0.221       0.336
# floors_4        0.3373      0.248      1.361      0.174      -0.149       0.823
# waterfr_1       0.7200      0.088      8.195      0.000       0.548       0.892
# cond_2         -0.3295      0.059     -5.609      0.000      -0.445      -0.214
# cond_5          0.1988      0.017     11.679      0.000       0.165       0.232
# grade_4        -1.7496      0.550     -3.180      0.001      -2.828      -0.671
# grade_5        -1.1839      0.107    -11.029      0.000      -1.394      -0.973
# grade_6        -0.7889      0.095     -8.337      0.000      -0.974      -0.603
# grade_7        -0.2468      0.094     -2.636      0.008      -0.430      -0.063
# grade_8         0.2159      0.094      2.306      0.021       0.032       0.399
# grade_9         0.6479      0.094      6.884      0.000       0.463       0.832
# grade_10        0.9032      0.096      9.415      0.000       0.715       1.091
# grade_11        1.0998      0.109     10.119      0.000       0.887       1.313
# grade_12        1.1726      0.550      2.131      0.033       0.094       2.251
# grade_13             0          0        nan        nan           0           0
# yr_built_2     -0.6605      0.013    -51.705      0.000      -0.686      -0.635
# yr_built_3     -0.7226      0.016    -45.383      0.000      -0.754      -0.691
# ==============================================================================
# Omnibus:                        9.523   Durbin-Watson:                   1.974
# Prob(Omnibus):                  0.009   Jarque-Bera (JB):                9.604
# Skew:                          -0.046   Prob(JB):                      0.00821
# Kurtosis:                       3.061   Cond. No.                     1.27e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 3.44e-20. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """

# %% [markdown]
# **Model assumption: Normality**
#
# * **Plot 1**: Histogram of the residuals
# * **Plot 2**: Q-Q plot of the residuals

# %%
# Calculate the residuals.
residuals = model3.resid

fig, axes = plt.subplots(1, 2, figsize = (8,4))

sns.histplot(residuals, ax=axes[0])
axes[0].set_xlabel("Residual Value")
axes[0].set_title("Histogram of Residuals")

sm.qqplot(residuals, line='s',ax = axes[1])
axes[1].set_title("QQ Plot")

plt.tight_layout()
plt.show()

# %% [markdown]
# ---
# # Model Validation

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split

X = df2.drop('price', axis=1)
y = df2['price']

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

linreg = LinearRegression()

linreg.fit(X_train, y_train)

LinearRegression()

y_hat_train = linreg.predict(X_train)
y_hat_test = linreg.predict(X_test)

train_mse = mean_squared_error(y_train, y_hat_train)
test_mse = mean_squared_error(y_test, y_hat_test)
print('Train Mean Squared Error:', train_mse)
print('Test Mean Squared Error: ', test_mse)
# Out:
# Train Mean Squared Error: 0.41300310594141654
# Test Mean Squared Error:  0.4218969728995109

# %%
# Using K-Fold Cross Validation to verify

X = df2.drop('price', axis=1)
y = df2['price']

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

linreg = LinearRegression()

linreg.fit(X_train, y_train)

LinearRegression()

y_hat_train = linreg.predict(X_train)
y_hat_test = linreg.predict(X_test)

from sklearn.model_selection import cross_validate
from sklearn.metrics import mean_squared_error

scoring = {'mse': 'neg_mean_squared_error'}
results = cross_validate(linreg, X, y, scoring=scoring, cv=10)

test_mse_scores = -results['test_mse']

train_predictions = linreg.predict(X)
train_mse = mean_squared_error(y, train_predictions)

print("Train Mean Squared Error:", train_mse)
print("Test Mean Squared Error:", test_mse_scores.mean())
# Out:
# Train Mean Squared Error: 0.4152267886983053
# Test Mean Squared Error: 0.41653353912899027

# %%
# Get top 5 variables

from sklearn.feature_selection import RFE

selector = RFE(linreg, n_features_to_select=5)
selector = selector.fit(X_train, y_train.values)

selector.support_
# Out:
# array([False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False,  True,
#         True,  True,  True,  True, False, False, False, False, False,
#        False, False])

# %%
selected_columns = X_train.columns[selector.support_]
linreg.fit(X_train[selected_columns], y_train)
print(selected_columns)
# Out:
# Index(['grade_4', 'grade_5', 'grade_6', 'grade_7', 'grade_8'], dtype='object')

# %%
model2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0